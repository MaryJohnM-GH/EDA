# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv(r"C:\Users\0147982\Documents\Training\wibd_practice\transactions.csv")
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 83488 entries, 0 to 83487
# Data columns (total 3 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   date          83488 non-null  object
#  1   store_nbr     83488 non-null  int64
#  2   transactions  83488 non-null  int64
# dtypes: int64(2), object(1)
# memory usage: 1.9+ MB

# %% [markdown]
# Assignment 1: Groupby
# Can you return a table containing the top 10 stores by total transactions in the data?
#
# Make sure they’re sorted from highest to lowest.
#
# Thanks!

# %%
df.groupby('store_nbr')[['transactions']].sum().sort_values(by='transactions',ascending = False).iloc[:10]
# Out:
#            transactions
# store_nbr
# 44              7273093
# 47              6535810
# 45              6201115
# 46              5990113
# 3               5366350
# 48              5107785
# 8               4637971
# 49              4574103
# 50              4384444
# 11              3972488

# %% [markdown]
# Can you get me the total transactions by store and month?
#
# Sort the table from first month to last, then by highest transactions to lowest within each month.

# %%
df['month'] = df['date'].astype('datetime64[ns]').dt.month
df.head()
# Out:
#          date  store_nbr  transactions  month
# 0  2013-01-01         25           770      1
# 1  2013-01-02          1          2111      1
# 2  2013-01-02          2          2358      1
# 3  2013-01-02          3          3487      1
# 4  2013-01-02          4          1922      1

# %%
(df
    .groupby(['store_nbr','month'])[['transactions']]
    .sum()
    .sort_values(['month','transactions'], ascending=[True,False])
)
# Out:
#                  transactions
# store_nbr month
# 44        1            628438
# 47        1            568824
# 45        1            538370
# 46        1            522763
# 3         1            463260
# ...                       ...
# 32        12            86167
# 21        12            84128
# 42        12            76741
# 29        12            76627
# 22        12            50650
#
# [641 rows x 1 columns]
