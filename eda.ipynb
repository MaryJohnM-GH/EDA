# %%
import pandas as pd

df = pd.read_csv(r"C:\Projects\training\WIBD\Notes - learning Path\datafiles\Pandas Part 1\bigmart_data.csv")

# %%
# Get the rows and columns in the dataframe
df.shape
# Out:
# (8523, 12)

# %%
# Identify any duplicate rows
df.duplicated().sum()
# Out:
# 0

# %%
df.head()
# Out:
#   Item_Identifier  Item_Weight Item_Fat_Content  Item_Visibility  \
# 0           FDA15         9.30          Low Fat         0.016047
# 1           DRC01         5.92          Regular         0.019278
# 2           FDN15        17.50          Low Fat         0.016760
# 3           FDX07        19.20          Regular         0.000000
# 4           NCD19         8.93          Low Fat         0.000000
#
#                Item_Type  Item_MRP Outlet_Identifier  \
# 0                  Dairy  249.8092            OUT049
# 1            Soft Drinks   48.2692            OUT018
# 2                   Meat  141.6180            OUT049
# 3  Fruits and Vegetables  182.0950            OUT010
# 4              Household   53.8614            OUT013
#
#    Outlet_Establishment_Year Outlet_Size Outlet_Location_Type  \
# 0                       1999      Medium               Tier 1
# 1                       2009      Medium               Tier 3
# ...

# %%
df.tail(10)
# Out:
#      Item_Identifier  Item_Weight Item_Fat_Content  Item_Visibility  \
# 8513           FDH31       12.000          Regular         0.020407
# 8514           FDA01       15.000          Regular         0.054489
# 8515           FDH24       20.700          Low Fat         0.021518
# 8516           NCJ19       18.600          Low Fat         0.118661
# 8517           FDF53       20.750              reg         0.083607
# 8518           FDF22        6.865          Low Fat         0.056783
# 8519           FDS36        8.380          Regular         0.046982
# 8520           NCJ29       10.600          Low Fat         0.035186
# 8521           FDN46        7.210          Regular         0.145221
# 8522           DRG01       14.800          Low Fat         0.044878
#
#                Item_Type  Item_MRP Outlet_Identifier  \
# 8513                Meat   99.9042            OUT035
# 8514              Canned   57.5904            OUT045
# 8515        Baking Goods  157.5288            OUT018
# ...

# %%
df.describe()
# Out:
#        Item_Weight  Item_Visibility     Item_MRP  Outlet_Establishment_Year  \
# count  7060.000000      8523.000000  8523.000000                8523.000000
# mean     12.857645         0.066132   140.992782                1997.831867
# std       4.643456         0.051598    62.275067                   8.371760
# min       4.555000         0.000000    31.290000                1985.000000
# 25%       8.773750         0.026989    93.826500                1987.000000
# 50%      12.600000         0.053931   143.012800                1999.000000
# 75%      16.850000         0.094585   185.643700                2004.000000
# max      21.350000         0.328391   266.888400                2009.000000
#
#        Item_Outlet_Sales
# count        8523.000000
# mean         2181.288914
# std          1706.499616
# min            33.290000
# 25%           834.247400
# 50%          1794.331000
# 75%          3101.296400
# max         13086.964800

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 8523 entries, 0 to 8522
# Data columns (total 12 columns):
#  #   Column                     Non-Null Count  Dtype
# ---  ------                     --------------  -----
#  0   Item_Identifier            8523 non-null   object
#  1   Item_Weight                7060 non-null   float64
#  2   Item_Fat_Content           8523 non-null   object
#  3   Item_Visibility            8523 non-null   float64
#  4   Item_Type                  8523 non-null   object
#  5   Item_MRP                   8523 non-null   float64
#  6   Outlet_Identifier          8523 non-null   object
#  7   Outlet_Establishment_Year  8523 non-null   int64
#  8   Outlet_Size                6113 non-null   object
#  9   Outlet_Location_Type       8523 non-null   object
#  10  Outlet_Type                8523 non-null   object
#  11  Item_Outlet_Sales          8523 non-null   float64
# dtypes: float64(4), int64(1), object(7)
# memory usage: 799.2+ KB

# %%
# Verifying if Outlet with Outlet_Identifier has any non null values
df[(df['Outlet_Identifier'] =='OUT045') & (df['Outlet_Size'].notnull())]
# Out:
# Empty DataFrame
# Columns: [Item_Identifier, Item_Weight, Item_Fat_Content, Item_Visibility, Item_Type, Item_MRP, Outlet_Identifier, Outlet_Establishment_Year, Outlet_Size, Outlet_Location_Type, Outlet_Type, Item_Outlet_Sales]
# Index: []

# %%
# Determine unique outlet sizes
print(df['Outlet_Size'].unique())
# Out:
# ['Medium' nan 'High' 'Small']

# %%
# Determine the outlet_size of each outlet_identifier that has null value
outlet_null_size = df[df['Outlet_Size'].isnull()]['Outlet_Identifier'].unique()
print(outlet_null_size)
# Out:
# ['OUT010' 'OUT045' 'OUT017']

# %%
# Count number of rows where outlet_size is null
print(df['Outlet_Size'].isnull().sum())
# Out:
# 2410

# %%
#Verify if the above value matches the total number of rows having Outlet_identifier as OUT010,OUT045 or OUT017
print(df[df['Outlet_Identifier'].isin(['OUT010', 'OUT045', 'OUT017'])].shape)
# Out:
# (2410, 12)

# %%
# The above values being similar shows that the stores sizes are not mentioned in the data for stores ['OUT010' 'OUT045' 'OUT017']

# %%
# Determine number of unique stores:
print(df['Outlet_Identifier'].unique())
# Out:
# ['OUT049' 'OUT018' 'OUT010' 'OUT013' 'OUT027' 'OUT045' 'OUT017' 'OUT046'
#  'OUT035' 'OUT019']

# %%
# We have ten stores that we are analysing

# %%
#Outlet_Location_Type values 
print(df['Outlet_Location_Type'].unique())
# Out:
# ['Tier 1' 'Tier 3' 'Tier 2']

# %%
# Number of items that are in the dataframe
print(df['Item_Type'].nunique())
# Out:
# 16

# %%
# #Outlet types
print(df['Outlet_Type'].unique())
# Out:
# ['Supermarket Type1' 'Supermarket Type2' 'Grocery Store'
#  'Supermarket Type3']

# %%
print(df['Outlet_Type'].value_counts())
# Out:
# Outlet_Type
# Supermarket Type1    5577
# Grocery Store        1083
# Supermarket Type3     935
# Supermarket Type2     928
# Name: count, dtype: int64

# %%
# Create dataframes of Small. medium and high size stores
# Small stores dataframe
df_small_stores = df[df['Outlet_Size'] == 'Small']
df_small_stores.head()
# Out:
#    Item_Identifier  Item_Weight Item_Fat_Content  Item_Visibility  \
# 11           FDA03        18.50          Regular         0.045464
# 13           FDS46        17.60          Regular         0.047257
# 15           FDP49         9.00          Regular         0.069089
# 19           FDU02        13.35          Low Fat         0.102492
# 22           NCB30        14.60          Low Fat         0.025698
#
#       Item_Type  Item_MRP Outlet_Identifier  Outlet_Establishment_Year  \
# 11        Dairy  144.1102            OUT046                       1997
# 13  Snack Foods  119.6782            OUT046                       1997
# 15    Breakfast   56.3614            OUT046                       1997
# 19        Dairy  230.5352            OUT035                       2004
# 22    Household  196.5084            OUT035                       2004
#
#    Outlet_Size Outlet_Location_Type        Outlet_Type  Item_Outlet_Sales
# ...

# %%
# #Outlet location types of small stores
print(df_small_stores['Outlet_Location_Type'].unique())
# Out:
# ['Tier 1' 'Tier 2']

# %%
# #Outlet types
print(df_small_stores['Outlet_Type'].unique())
# Out:
# ['Supermarket Type1' 'Grocery Store']

# %%
print(df_small_stores.Item_Type.unique())
# Out:
# ['Dairy' 'Snack Foods' 'Breakfast' 'Household' 'Baking Goods'
#  'Frozen Foods' 'Canned' 'Soft Drinks' 'Health and Hygiene' 'Meat'
#  'Fruits and Vegetables' 'Starchy Foods' 'Others' 'Breads' 'Hard Drinks'
#  'Seafood']

# %%
print(df_small_stores.Item_Type.nunique())
# Out:
# 16

# %%
df_small_stores.describe()
# Out:
#        Item_Weight  Item_Visibility     Item_MRP  Outlet_Establishment_Year  \
# count  1860.000000      2388.000000  2388.000000                2388.000000
# mean     12.848075         0.071383   141.970209                1997.072864
# std       4.693634         0.057272    62.084107                   7.137096
# min       4.555000         0.000000    32.055800                1985.000000
# 25%       8.670000         0.027778    94.991650                1997.000000
# 50%      12.600000         0.057810   144.279900                1997.000000
# 75%      16.850000         0.102402   186.042400                2004.000000
# max      21.350000         0.328391   266.888400                2004.000000
#
#        Item_Outlet_Sales
# count        2388.000000
# mean         1912.149161
# std          1582.370364
# min            33.955800
# 25%           601.050950
# 50%          1544.656000
# 75%          2824.323600
# max          9779.936200

# %%
# create sub dataframe for medium and high size stor and run the same analysis as above
df_medium_stores = df[df['Outlet_Size'] == 'Medium']
df_high_stores = df[df['Outlet_Size'] == 'High']

# %%
df_medium_stores.describe()
# Out:
#        Item_Weight  Item_Visibility     Item_MRP  Outlet_Establishment_Year  \
# count  1858.000000      2793.000000  2793.000000                2793.000000
# mean     12.895420         0.060142   140.590514                1997.635875
# std       4.651906         0.044382    62.147571                   9.849561
# min       4.555000         0.000000    31.290000                1985.000000
# 25%       8.810000         0.026074    93.809400                1985.000000
# 50%      12.625000         0.048842   142.015400                1999.000000
# 75%      17.000000         0.086984   185.089800                2009.000000
# max      21.350000         0.188323   266.288400                2009.000000
#
#        Item_Outlet_Sales
# count        2793.000000
# mean         2681.603542
# std          1855.210528
# min            69.243200
# 25%          1270.346400
# 50%          2251.069800
# 75%          3691.195200
# max         13086.964800

# %%
# #Outlet types
print(df_medium_stores['Outlet_Type'].unique())
# Out:
# ['Supermarket Type1' 'Supermarket Type2' 'Supermarket Type3']

# %%
# #Outlet location types of medium stores
print(df_medium_stores['Outlet_Location_Type'].unique())
# Out:
# ['Tier 1' 'Tier 3']

# %%
df_high_stores.describe()
# Out:
#        Item_Weight  Item_Visibility    Item_MRP  Outlet_Establishment_Year  \
# count   932.000000       932.000000  932.000000                      932.0
# mean     13.006148         0.059957  141.425982                     1987.0
# std       4.666798         0.044235   62.890605                        0.0
# min       4.555000         0.000000   31.490000                     1987.0
# 25%       8.891250         0.026109   93.245550                     1987.0
# 50%      12.850000         0.049587  142.047000                     1987.0
# 75%      17.025000         0.086466  186.938500                     1987.0
# max      21.350000         0.185705  266.688400                     1987.0
#
#        Item_Outlet_Sales
# count         932.000000
# mean         2298.995256
# std          1533.531664
# min            73.238000
# 25%          1072.603800
# 50%          2050.664000
# 75%          3166.378350
# max         10256.649000

# %%
# #Outlet types
print(df_high_stores['Outlet_Type'].unique())
# Out:
# ['Supermarket Type1']

# %%
# #Outlet location types of high stores
print(df_high_stores['Outlet_Location_Type'].unique())
# Out:
# ['Tier 3']

# %%
# OUT045 outlet type and location type

# %%
print(df[df['Outlet_Identifier'] == 'OUT045']['Outlet_Type'].unique())
# Out:
# ['Supermarket Type1']

# %%
print(df[df['Outlet_Identifier'] == 'OUT045']['Outlet_Location_Type'].unique())
# Out:
# ['Tier 2']

# %%
# Based on the anaylsis done by checking the location type of small, medium, and high stores Outlet_Location_Type and Outlet_Type
# we can deduce that OUT045 can have Outlet_Size = OUT045

# %%
# OUT010 outlet type and location type

# %%
print(df[df['Outlet_Identifier'] == 'OUT010']['Outlet_Type'].unique())
# Out:
# ['Grocery Store']

# %%
print(df[df['Outlet_Identifier'] == 'OUT010']['Outlet_Location_Type'].unique())
# Out:
# ['Tier 3']

# %%
# OUT017 outlet has Outlet_Type = Grocery which is only availble amont small size outlets, hence the null values can be replaced with small

# %%
# OUT017 outlet type and location type

# %%
print(df[df['Outlet_Identifier'] == 'OUT017']['Outlet_Type'].unique())
# Out:
# ['Supermarket Type1']

# %%
print(df[df['Outlet_Identifier'] == 'OUT017']['Outlet_Location_Type'].unique())
# Out:
# ['Tier 2']

# %%
# OUT017 can also be small size stores since only they have this combination of store type and location type

# %%
# Get shape of each subdata frame
print(df_small_stores.shape)
print(df_medium_stores.shape)
print(df_high_stores.shape)
# Out:
# (2388, 12)
# (2793, 12)
# (932, 12)

# %%
# Print summary of all data types
df.describe(include = 'all')
# Out:
#        Item_Identifier  Item_Weight Item_Fat_Content  Item_Visibility  \
# count             8523  7060.000000             8523      8523.000000
# unique            1559          NaN                5              NaN
# top              FDW13          NaN          Low Fat              NaN
# freq                10          NaN             5089              NaN
# mean               NaN    12.857645              NaN         0.066132
# std                NaN     4.643456              NaN         0.051598
# min                NaN     4.555000              NaN         0.000000
# 25%                NaN     8.773750              NaN         0.026989
# 50%                NaN    12.600000              NaN         0.053931
# 75%                NaN    16.850000              NaN         0.094585
# max                NaN    21.350000              NaN         0.328391
#
#                     Item_Type     Item_MRP Outlet_Identifier  \
# count                    8523  8523.000000              8523
# ...

# %%
# Count of missing values per column
df.isnull().sum()
# Out:
# Item_Identifier                 0
# Item_Weight                  1463
# Item_Fat_Content                0
# Item_Visibility                 0
# Item_Type                       0
# Item_MRP                        0
# Outlet_Identifier               0
# Outlet_Establishment_Year       0
# Outlet_Size                  2410
# Outlet_Location_Type            0
# Outlet_Type                     0
# Item_Outlet_Sales               0
# dtype: int64

# %%
# create a sub dataframe where the Item_Weight is null
df_item_weight_null = df[df['Item_Weight'].isnull()]
df_item_weight_null.head()
# Out:
#    Item_Identifier  Item_Weight Item_Fat_Content  Item_Visibility  \
# 7            FDP10          NaN          Low Fat         0.127470
# 18           DRI11          NaN          Low Fat         0.034238
# 21           FDW12          NaN          Regular         0.035400
# 23           FDC37          NaN          Low Fat         0.057557
# 29           FDC14          NaN          Regular         0.072222
#
#        Item_Type  Item_MRP Outlet_Identifier  Outlet_Establishment_Year  \
# 7    Snack Foods  107.7622            OUT027                       1985
# 18   Hard Drinks  113.2834            OUT027                       1985
# 21  Baking Goods  144.5444            OUT027                       1985
# 23  Baking Goods  107.6938            OUT019                       1985
# 29        Canned   43.6454            OUT019                       1985
#
#    Outlet_Size Outlet_Location_Type        Outlet_Type  Item_Outlet_Sales
# ...

# %%
df_item_weight_null.describe(include='all')
# Out:
#        Item_Identifier  Item_Weight Item_Fat_Content  Item_Visibility  \
# count             1463          0.0             1463      1463.000000
# unique            1142          NaN                5              NaN
# top              FDK08          NaN          Low Fat              NaN
# freq                 2          NaN              867              NaN
# mean               NaN          NaN              NaN         0.076597
# std                NaN          NaN              NaN         0.063012
# min                NaN          NaN              NaN         0.000000
# 25%                NaN          NaN              NaN         0.029545
# 50%                NaN          NaN              NaN         0.060588
# 75%                NaN          NaN              NaN         0.110718
# max                NaN          NaN              NaN         0.328391
#
#                     Item_Type     Item_MRP Outlet_Identifier  \
# count                    1463  1463.000000              1463
# ...

# %%
df_item_weight_null['Outlet_Identifier'].unique()
# Out:
# array(['OUT027', 'OUT019'], dtype=object)
